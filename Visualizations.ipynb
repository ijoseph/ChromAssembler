# %%
# %config InlineBackend.figure_format = 'retina'

# %%
import Assemble
import AssembleVisualize

# %% [markdown]
# # Make Assembly

# %%
assemble_obj = Assemble.Assembler(file("Data/coding_challenge_data_set.txt"))
assemble_obj.assemble()
# Out:
# '...'

# %% [markdown]
# # Visualize Fragment Lengths

# %%
AssembleVisualize.DeBruijnGraphVisualize.show_fragment_length_distribution(assemble_obj.assembler)

# %% [markdown]
# ⇒ it's reasonable to do $ k \leftarrow \lfloor \frac{\min(\text{fragment length})}{2} \rfloor $

# %% [markdown]
# # Look at De Bruijn Graph

# %%
test_assemble_obj = Assemble.Assembler(file("Data/coding_challenge_data_set_example.txt"))

# %%
AssembleVisualize.DeBruijnGraphVisualize.to_dot(test_assemble_obj.assembler)

# %%
test_assemble_obj.assemble()
# Out:
# 'ATTAGACCTGCCGGAATAC'

# %% [markdown]
# ⇒ looks good
